# %% [markdown]
# <a href="https://colab.research.google.com/github/gfeyzakorkmaz/Tries/blob/main/P11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
path = '/content/drive/MyDrive/Dataset/complex_marketing_data_enriched.xlsx'

# %%
df = pd.read_excel(path)
df.head(3)
# Out:
#    Customer ID  Age Gender  Total Spent  Converted  \
# 0            1   23      F          150          1
# 1            2   35      M          600          1
# 2            3   45      F          800          0
#
#                         Comments Purchased Category  Stock Region  \
# 0     Satisfied with the service           Clothing      4   East
# 1  Needs improvement in delivery             Beauty     86   West
# 2               Regular customer              Books     24  North
#
#   Income Level  ...      Campaign  Return Rate (%) Website Visit Frequency  \
# 0       Medium  ...   Winter Sale         2.981829                       3
# 1          Low  ...   Summer Sale         1.833412                       6
# 2       Medium  ...  Black Friday         6.547401                       0
#
#    Average Cart Value  Total Spent Diff  Spending Rank  Rolling Return Rate  \
# 0              378.00               NaN           19.0                  NaN
# ...

# %%
correlation = df['Total Spent'].corr(df['Return Rate (%)'])
print("Correlation between rates and spending:", correlation)
# Out:
# Correlation between rates and spending: 0.07364476559722229

# %%
df['roi'] = (df['Total Spent'] - df['Return Rate (%)']) / df['Return Rate (%)']
campaign_roi = df.groupby('Campaign')['roi'].mean().reset_index()
campaign_roi
# Out:
#        Campaign         roi
# 0  Black Friday   91.603897
# 1   Summer Sale  179.614385
# 2   Winter Sale   92.686665

# %%
df['churn_risk'] = pd.cut(df['Return Rate (%)'], bins=[0, 0.25, 0.75, 1], labels=['Low', 'Medium', 'High'])
df[['Return Rate (%)', 'churn_risk']].head()
# Out:
#    Return Rate (%) churn_risk
# 0         2.981829        NaN
# 1         1.833412        NaN
# 2         6.547401        NaN
# 3         3.923717        NaN
# 4         2.306644        NaN

# %%
spending_by_region_age = df.groupby(['Region', 'Age'])['Total Spent'].sum().unstack()
spending_by_region_age
# Out:
# Age        23     24     25     27     28     29     32     33      35     36  \
# Region
# East    150.0  290.0  400.0    NaN    NaN  300.0  320.0    NaN     NaN    NaN
# North     NaN    NaN    NaN  120.0  350.0    NaN    NaN    NaN     NaN    NaN
# South     NaN    NaN    NaN    NaN    NaN    NaN    NaN  750.0     NaN    NaN
# West      NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN  1300.0  510.0
#
# Age        38     40     41     42     45     48     50     52
# Region
# East      NaN  610.0    NaN    NaN    NaN  400.0  500.0  200.0
# North   670.0    NaN    NaN    NaN  800.0    NaN    NaN    NaN
# South     NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# West      NaN    NaN  450.0  550.0    NaN    NaN  250.0    NaN

# %%
df['conversion_rate'] = (df['Converted'] / df['Website Visit Frequency']).fillna(0)
df[['Website Visit Frequency', 'Converted', 'conversion_rate']].head()
# Out:
#    Website Visit Frequency  Converted  conversion_rate
# 0                        3          1         0.333333
# 1                        6          1         0.166667
# 2                        0          0         0.000000
# 3                        1          0         0.000000
# 4                        4          1         0.250000

# %%
pivot_table = df.pivot_table(values=['Total Spent', 'Return Rate (%)'], index='Campaign', columns='Region', aggfunc='mean')
pivot_table
# Out:
#              Return Rate (%)                     Total Spent
# Region                  East     North      West        East  North   West
# Campaign
# Black Friday        5.131520  6.547401  4.644536       305.0  800.0  550.0
# Summer Sale              NaN       NaN  4.596422         NaN    NaN  425.0
# Winter Sale         4.228114  5.069016       NaN       360.0  380.0    NaN

# %%
df['spending_segment'] = pd.cut(df['Total Spent'], bins=[0, 500, 1000, 5000], labels=['Low', 'Medium', 'High'])
df[['Total Spent', 'spending_segment']].head()
# Out:
#    Total Spent spending_segment
# 0          150              Low
# 1          600           Medium
# 2          800           Medium
# 3          200              Low
# 4          300              Low

# %%
summary_for_tableau = df.groupby(['Campaign', 'Region']).agg({
    'Total Spent': 'sum',
    'Return Rate (%)': 'mean',
    'Spending Rank': 'mean'
}).reset_index()

summary_for_tableau.to_csv('summary_for_tableau.csv', index=False)

print(summary_for_tableau)
# Out:
#        Campaign Region  Total Spent  Return Rate (%)  Spending Rank
# 0  Black Friday   East          610         5.131520      15.000000
# 1  Black Friday  North          800         6.547401       1.000000
# 2  Black Friday   West          550         4.644536       7.000000
# 3   Summer Sale   West          850         4.596422      11.500000
# 4   Winter Sale   East         2160         4.228114      12.916667
# 5   Winter Sale  North         1140         5.069016      12.333333

# %%
import os
print(os.getcwd())
# Out:
# /content
