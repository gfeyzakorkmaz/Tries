# %% [markdown]
# <a href="https://colab.research.google.com/github/gfeyzakorkmaz/Tries/blob/main/Unpivoted.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

path = '/content/drive/MyDrive/Dataset/complex_marketing_data_enriched.xlsx'

df = pd.read_excel(path)
df.head()

pivoted = df.pivot_table(
    values='Total Spent',
    index='Region',
    columns='Purchased Category',
    aggfunc='sum',
    fill_value=0
)

unpivoted = pivoted.reset_index().melt(
    id_vars='Region',
    var_name='Purchased Category',
    value_name='Total Spent'
)

print("\nUnpivoted Data:")
print(unpivoted)
# Out:
# Unpivoted Data:
#    Region Purchased Category  Total Spent
# 0    East             Beauty          600
# 1   North             Beauty            0
# 2   South             Beauty            0
# 3    West             Beauty          600
# 4    East              Books          300
# 5   North              Books          800
# 6   South              Books            0
# 7    West              Books         1250
# 8    East           Clothing          150
# 9   North           Clothing            0
# 10  South           Clothing          750
# 11   West           Clothing          700
# 12   East        Electronics          820
# 13  North        Electronics          350
# 14  South        Electronics            0
# 15   West        Electronics          510
# 16   East         Home Goods         1300
# 17  North         Home Goods          790
# 18  South         Home Goods            0
# 19   West         Home Goods            0

# %%
df = pd.read_excel(path)
df.head()
# Out:
#    Customer ID  Age Gender  Total Spent  Converted  \
# 0            1   23      F          150          1
# 1            2   35      M          600          1
# 2            3   45      F          800          0
# 3            4   52      M          200          0
# 4            5   29      F          300          1
#
#                         Comments Purchased Category  Stock Region  \
# 0     Satisfied with the service           Clothing      4   East
# 1  Needs improvement in delivery             Beauty     86   West
# 2               Regular customer              Books     24  North
# 3               Occasional buyer             Beauty     10   East
# 4                   High spender              Books     47   East
#
#   Income Level  ...      Campaign  Return Rate (%) Website Visit Frequency  \
# 0       Medium  ...   Winter Sale         2.981829                       3
# 1          Low  ...   Summer Sale         1.833412                       6
# 2       Medium  ...  Black Friday         6.547401                       0
# 3       Medium  ...   Winter Sale         3.923717                       1
# 4       Medium  ...   Winter Sale         2.306644                       4
#
#    Average Cart Value  Total Spent Diff  Spending Rank  Rolling Return Rate  \
# 0              378.00               NaN           19.0                  NaN
# 1              315.52             450.0            6.0                  NaN
# 2              250.69             200.0            1.0             3.787547
# 3              222.58            -600.0           18.0             4.101510
# 4              298.68             100.0           15.0             4.259254
#
#    High Spender  Customer Tenure Quarter Customer Word Count
# 0            No                       Q1                   0
# 1           Yes                       Q3                   0
# 2           Yes                       Q3                   1
# 3            No                       Q2                   0
# 4            No                       Q3                   0
#
# [5 rows x 22 columns]

# %%
import pandas as pd

path = '/content/drive/MyDrive/Dataset/complex_marketing_data_enriched.xlsx'

df = pd.read_excel(path)

customers = pd.DataFrame({
    'Customer ID',
    'Age',
    'Region'
})

spending = pd.DataFrame({
    'Customer ID',
    'Total Spent'
})

merged = pd.merge(customers, spending, on='Customer ID')
print("Merged Data:")
print(merged)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-9-6c37c5a12c29> in <cell line: 0>()
#      16 })
#      17
# ---> 18 merged = pd.merge(customers, spending, on='Customer ID')
#      19 print("Merged Data:")
#      20 print(merged)
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     168         )
#     169     else:
# --> 170         op = _MergeOperation(
#     171             left_df,
#     172             right_df,
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/reshape/merge.py in __init__(self, left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, indicator, validate)
#     792             left_drop,
#     793             right_drop,
# --> 794         ) = self._get_merge_keys()
#     795
#     796         if left_drop:
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/reshape/merge.py in _get_merge_keys(self)
#    1295                         rk = cast(Hashable, rk)
#    1296                         if rk is not None:
# -> 1297                             right_keys.append(right._get_label_or_level_values(rk))
#    1298                         else:
#    1299                             # work-around for merge_asof(right_index=True)
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in _get_label_or_level_values(self, key, axis)
#    1909             values = self.axes[axis].get_level_values(key)._values
#    1910         else:
# -> 1911             raise KeyError(key)
#    1912
#    1913         # Check for duplicates
#
# KeyError: 'Customer ID'

# %%
import pandas as pd

path = '/content/drive/MyDrive/Dataset/complex_marketing_data_enriched.xlsx'

df = pd.read_excel(path)


customers = pd.DataFrame(columns=['Customer ID', 'Age', 'Region'])
spending = pd.DataFrame(columns=['Customer ID', 'Total Spent'])



customers = pd.DataFrame(customers, columns=customers.columns)
spending = pd.DataFrame(spending, columns=spending.columns)

merged = pd.merge(customers, spending, on='Customer ID')
print("Merged Data:")
print(merged)
# Out:
# Merged Data:
# Empty DataFrame
# Columns: [Customer ID, Age, Region, Total Spent]
# Index: []

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive
